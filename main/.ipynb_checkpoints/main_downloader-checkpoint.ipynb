# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /opt/miniconda3/envs/ee/lib/python3.10/site-packages (4.66.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the CSV file
csv_file = '/Users/joshmanto/Downloads/BB/tree-semantics/lats-longs-csv/locations.csv'
data = pd.read_csv(csv_file)

# Display the first few rows of the data
print(data.head())
# Out:
#    longitude   latitude
# 0  28.029352 -26.248023
# 1  28.009093 -26.207037
# 2  28.028533 -26.136593
# 3  28.040460 -26.133520
# 4  27.587758 -26.040437

# %% [markdown]
# CLUSTER LAT AND LONG USING DBSCAN SCIKIT
# STORE AS VARIABLES TO BE SENT AS INPUT

# %%
from sklearn.cluster import DBSCAN
import numpy as np

# Extract latitude and longitude
coords = data[['latitude', 'longitude']].values

# Define the DBSCAN clustering parameters
epsilon = 0.01  # Adjust the value as needed
min_samples = 5

# Apply DBSCAN clustering
db = DBSCAN(eps=epsilon, min_samples=min_samples, metric='haversine').fit(np.radians(coords))
labels = db.labels_

# Add the cluster labels to the data
data['cluster'] = labels

# Display the clustered data
print(data.head(50))
# Out:
#     longitude   latitude  cluster
# 0   28.029352 -26.248023        0
# 1   28.009093 -26.207037        0
# 2   28.028533 -26.136593        0
# 3   28.040460 -26.133520        0
# 4   27.587758 -26.040437        0
# 5   28.120983 -25.489502       -1
# 6   25.865823 -24.669195       -1
# 7   25.875787 -24.654352       -1
# 8   57.462418 -20.234445       -1
# 9   57.582078 -20.096572       -1
# 10  57.584127 -20.067255       -1
# 11 -13.411811  27.097262       -1
# 12  -9.547540  30.352274       -1
# 13  -8.028289  31.621362       -1
# 14  -9.227294  32.276417       -1
# 15  -7.657850  33.522778       -1
# 16  -7.660924  33.528330       -1
# 17  -7.608301  33.566550       -1
# 18  -7.532156  33.615298       -1
# 19  -6.871319  33.951440       -1
# 20  -6.733552  33.995864       -1
# 21  -1.917905  34.661148       -1
# 22  -1.895867  34.707470       -1
# 23  10.748792  36.472305       -1
# 24  10.085372  36.830607       -1
# 25  28.919330 -31.381882       -1
# 26  27.219763 -30.600395       -1
# 27  28.515602 -30.351668       -1
# 28  27.437025 -30.190613       -1
# 29  27.948570 -30.071482       -1
# 30  27.474390 -29.904865       -1
# 31  27.369070 -29.506180       -1
# 32  27.558532 -29.318150        1
# 33  27.878180 -29.119957        1
# 34  31.545263 -29.081272       -1
# 35  27.781255 -29.038460        1
# 36  31.369738 -29.028382       -1
# 37  28.154377 -28.935910        1
# 38  28.042842 -28.860718        1
# 39  28.075698 -28.667095        1
# 40  24.399963 -28.103154       -1
# 41  30.628180 -28.082915       -1
# 42  31.767108 -27.832893        2
# 43  24.811772 -27.664277       -1
# 44  31.881277 -27.304450        2
# 45  31.511462 -27.300715        2
# 46  31.345926 -27.186966        2
# 47  31.926145 -27.080905        2
# 48  31.594947 -27.057522        2
# 49  31.120972 -27.005346        2

# %%
# Store clustered coordinates with increasing filenames
clustered_coords = {}

for cluster_label in np.unique(labels):
    if cluster_label != -1:  # Ignore noise points
        cluster_data = data[data['cluster'] == cluster_label]
        clustered_coords[f'AOI{cluster_label + 1}'] = cluster_data[['latitude', 'longitude']].values.tolist()

# Display the clustered coordinates
for aoi, coords in clustered_coords.items():
# AOI10: [[9.17190667, 42.072], [9.27875667, 42.701405], [9.30211167, 42.10254667], [9.329545, 42.23605], [9.33526667, 42.17011333], [9.39039667, 42.20064833]]
# AOI11: [[10.571992, -9.515568], [10.85050333, -9.470435], [10.96111, -9.190708], [11.06818, -9.365212], [11.225082, -8.977978], [11.435433, -9.120147], [11.681983, -9.075228]]
# AOI12: [[13.302963333333333, -14.309094999999996], [13.338278333333337, -14.403764999999998], [13.386661666666663, -13.862076666666669], [13.543958333333334, -13.995824999999998], [13.58489, -15.423585], [13.598601666666664, -14.692211666666667], [13.660606666666668, -14.846801666666666], [13.78155, -14.938788333333331]]

# %% [markdown]
# AUTHENTICATION AND ENDPOINTS

# %%
import requests
import json
from datetime import datetime

# API key for Planet.com
API_KEY = 'PLAK38d647437d504a2da7e86373e0356771'
auth = (API_KEY, '')

# Base URL for the Planet API
BASE_URL = "https://api.planet.com/data/v1"

# %% [markdown]
# PARAMETERS AND FILTERS.

# %%
from shapely.geometry import box, mapping
import datetime

# TIME AND CLOUD COVER PARAMETER DEFAULTS 
start_date = "2020-01-01T00:00:00.000Z"
end_date = "2020-02-01T00:00:00.000Z"
max_cloud_cover = 0.5

# HELPER (CREATE BOUNDING BOX) 
def create_bounding_box(coords):
    lats, lons = zip(*coords)
    return box(min(lons), min(lats), max(lons), max(lats))

# MAIN FUNCTION. SOURCES HELPER. 
def create_filters(coords):
    bounding_box = create_bounding_box(coords)
    geojson_geometry = mapping(bounding_box)
    
    geometry_filter = {
        "type": "GeometryFilter",
        "field_name": "geometry",
        "config": geojson_geometry
    }

    date_range_filter = {
        "type": "DateRangeFilter",
        "field_name": "acquired",
        "config": {
            "gte": start_date,
            "lte": end_date
        }
    }

    cloud_cover_filter = {
        "type": "RangeFilter",
        "field_name": "cloud_cover",
        "config": {
            "lte": max_cloud_cover
        }
    }

    combined_filter = {
        "type": "AndFilter",
        "config": [geometry_filter, date_range_filter, cloud_cover_filter]
    }
    
    return combined_filter

# %%
#CREATE FILTER FOR FIRST TWO AOIs ONLY. 
filters_AOI1 = create_filters(clustered_coords['AOI1'])
filters_AOI2 = create_filters(clustered_coords['AOI2'])

# %%
import json
#test to see if the filters and AOIs are tagged properly
print("Filter for AOI1:")
print(json.dumps(filters_AOI1, indent=2))

print("\nFilter for AOI2:")
print(json.dumps(filters_AOI2, indent=2))
# Out:
# Filter for AOI1:
# {
#   "type": "AndFilter",
#   "config": [
#     {
#       "type": "GeometryFilter",
#       "field_name": "geometry",
#       "config": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               28.04046,
#               -26.248023333333336
#             ],
#             [
#               28.04046,
#               -25.56795833333333
#             ],
#             [
#               27.246971666666663,
#               -25.56795833333333
#             ],
#             [
#               27.246971666666663,
#               -26.248023333333336
#             ],
#             [
#               28.04046,
#               -26.248023333333336
#             ]
#           ]
#         ]
#       }
#     },
#     {
#       "type": "DateRangeFilter",
#       "field_name": "acquired",
#       "config": {
#         "gte": "2020-01-01T00:00:00.000Z",
#         "lte": "2020-02-01T00:00:00.000Z"
#       }
#     },
#     {
#       "type": "RangeFilter",
#       "field_name": "cloud_cover",
#       "config": {
#         "lte": 0.5
#       }
#     }
#   ]
# }
#
# Filter for AOI2:
# {
#   "type": "AndFilter",
#   "config": [
#     {
#       "type": "GeometryFilter",
#       "field_name": "geometry",
#       "config": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               28.154376666666668,
#               -29.31815
#             ],
#             [
#               28.154376666666668,
#               -28.667095000000003
#             ],
#             [
#               27.558531666666667,
#               -28.667095000000003
#             ],
#             [
#               27.558531666666667,
#               -29.31815
#             ],
#             [
#               28.154376666666668,
#               -29.31815
#             ]
#           ]
#         ]
#       }
#     },
#     {
#       "type": "DateRangeFilter",
#       "field_name": "acquired",
#       "config": {
#         "gte": "2020-01-01T00:00:00.000Z",
#         "lte": "2020-02-01T00:00:00.000Z"
#       }
#     },
#     {
#       "type": "RangeFilter",
#       "field_name": "cloud_cover",
#       "config": {
#         "lte": 0.5
#       }
#     }
#   ]
# }

# %% [markdown]
# POST REQUEST THAT WILL PRINT THE FIRST IN THE LIST OF RESULTS

# %%
from requests.auth import HTTPBasicAuth
# Function to send POST request
def send_post_request(filters, item_type="PSScene"):
    search_request = {
        "item_types": [item_type],
        "filter": filters
    }
    
    search_result = requests.post(
        'https://api.planet.com/data/v1/quick-search',
        auth=HTTPBasicAuth(API_KEY, ''),
        json=search_request
    )
    
    geojson = search_result.json()
    
    # Print the first result
    if 'features' in geojson and geojson['features']:
        print(json.dumps(geojson['features'][0], indent=2))
    else:
        print("No results found.")


# Send POST requests
print("Results for AOI1:")
send_post_request(filters_AOI1)

print("\nResults for AOI2:")
send_post_request(filters_AOI2)
# Out:
# Results for AOI1:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200105_092927_42_1069",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200105_092927_42_1069/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200105_092927_42_1069/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           26.998168259478046,
#           -25.71678216687225
#         ],
#         [
#           27.031598851182288,
#           -25.865514456241744
#         ],
#         [
#           27.279999304364807,
#           -25.819915312077814
#         ],
#         [
#           27.246028190049074,
#           -25.670449160851053
#         ],
#         [
#           26.998168259478046,
#           -25.71678216687225
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200105_092927_42_1069",
#   "properties": {
#     "acquired": "2020-01-05T09:29:27.429082Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 95,
#     "clear_percent": 86,
#     "cloud_cover": 0.07,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 7,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 7,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2023-08-13T01:46:59Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 263.5,
#     "satellite_id": "1069",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3002715",
#     "sun_azimuth": 76.9,
#     "sun_elevation": 78.4,
#     "updated": "2023-08-13T01:46:59Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 70,
#     "visible_percent": 93
#   },
#   "type": "Feature"
# }
#
# Results for AOI2:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200121_092611_01_106b",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200121_092611_01_106b/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200121_092611_01_106b/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           28.11402436943163,
#           -29.30468499088462
#         ],
#         [
#           28.14930282221496,
#           -29.45454504389222
#         ],
#         [
#           28.4070594144298,
#           -29.40813848030144
#         ],
#         [
#           28.371672378997893,
#           -29.257645644472642
#         ],
#         [
#           28.11402436943163,
#           -29.30468499088462
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200121_092611_01_106b",
#   "properties": {
#     "acquired": "2020-01-21T09:26:11.01285Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 76,
#     "clear_percent": 47,
#     "cloud_cover": 0.45,
#     "cloud_percent": 45,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 5,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2023-08-13T05:57:07Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 263.5,
#     "satellite_id": "106b",
#     "shadow_percent": 3,
#     "snow_ice_percent": 0,
#     "strip_id": "3055185",
#     "sun_azimuth": 55.2,
#     "sun_elevation": 74.7,
#     "updated": "2023-08-13T05:57:07Z",
#     "view_angle": 4,
#     "visible_confidence_percent": 59,
#     "visible_percent": 55
#   },
#   "type": "Feature"
# }

# %% [markdown]
# POST REQUEST THAT WILL SEND ALL THE AVAILABLE RESULTS

# %%
def send_post_request(filters, item_type="PSScene"):
    search_request = {
        "item_types": [item_type],
        "filter": filters
    }
    
    search_result = requests.post(
        'https://api.planet.com/data/v1/quick-search',
        auth=HTTPBasicAuth(API_KEY, ''),
        json=search_request
    )
    
    geojson = search_result.json()
    
    if 'features' in geojson and geojson['features']:
        total_results = len(geojson['features'])
        print(f"Total number of results: {total_results}")
        for feature in geojson['features']:
            print(json.dumps(feature, indent=2))
        return geojson['features']
    else:
        print("No results found.")
        return []

# Send POST requests and get results
print("Results for AOI1:")
features_AOI1 = send_post_request(filters_AOI1)

print("\nResults for AOI2:")
features_AOI2 = send_post_request(filters_AOI2)
# Out:
# Results for AOI1:
# Total number of results: 250
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200105_092927_42_1069",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200105_092927_42_1069/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200105_092927_42_1069/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           26.998168259478046,
#           -25.71678216687225
#         ],
#         [
#           27.031598851182288,
#           -25.865514456241744
#         ],
#         [
#           27.279999304364807,
#           -25.819915312077814
#         ],
#         [
#           27.246028190049074,
#           -25.670449160851053
#         ],
#         [
#           26.998168259478046,
#           -25.71678216687225
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200105_092927_42_1069",
#   "properties": {
#     "acquired": "2020-01-05T09:29:27.429082Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 95,
#     "clear_percent": 86,
#     "cloud_cover": 0.07,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 7,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 7,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2023-08-13T01:46:59Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 263.5,
#     "satellite_id": "1069",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3002715",
#     "sun_azimuth": 76.9,
#     "sun_elevation": 78.4,
#     "updated": "2023-08-13T01:46:59Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 70,
#     "visible_percent": 93
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200105_092925_39_1069",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200105_092925_39_1069/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200105_092925_39_1069/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.02709675260968,
#           -25.84540613755611
#         ],
#         [
#           27.0606317142654,
#           -25.994108039954668
#         ],
#         [
#           27.308986963375517,
#           -25.948474938264525
#         ],
#         [
#           27.275130614734568,
#           -25.799133798570452
#         ],
#         [
#           27.02709675260968,
#           -25.84540613755611
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200105_092925_39_1069",
#   "properties": {
#     "acquired": "2020-01-05T09:29:25.39799Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 88,
#     "clear_percent": 33,
#     "cloud_cover": 0.48,
#     "cloud_percent": 2,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 47,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 19,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2023-08-13T01:46:30Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 263.4,
#     "satellite_id": "1069",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3002715",
#     "sun_azimuth": 76.2,
#     "sun_elevation": 78.4,
#     "updated": "2023-08-13T01:46:30Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 70,
#     "visible_percent": 52
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200126_082142_96_105d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200126_082142_96_105d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200126_082142_96_105d/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.424943546790473,
#           -26.24787834596014
#         ],
#         [
#           27.391845728741792,
#           -26.394911339822364
#         ],
#         [
#           27.637978693067563,
#           -26.440062130157475
#         ],
#         [
#           27.67105857376412,
#           -26.29233766610604
#         ],
#         [
#           27.424943546790473,
#           -26.24787834596014
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200126_082142_96_105d",
#   "properties": {
#     "acquired": "2020-01-26T08:21:42.960665Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 87,
#     "clear_percent": 62,
#     "cloud_cover": 0.27,
#     "cloud_percent": 17,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 10,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 9,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2023-08-11T19:37:50Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 280.2,
#     "satellite_id": "105d",
#     "shadow_percent": 2,
#     "snow_ice_percent": 0,
#     "strip_id": "3072924",
#     "sun_azimuth": 81.4,
#     "sun_elevation": 61,
#     "updated": "2023-08-11T19:37:50Z",
#     "view_angle": 4,
#     "visible_confidence_percent": 66,
#     "visible_percent": 73
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200126_082138_89_105d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200126_082138_89_105d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200126_082138_89_105d/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.482847725980587,
#           -25.9904458795519
#         ],
#         [
#           27.449927461708572,
#           -26.137435169541604
#         ],
#         [
#           27.69523723533399,
#           -26.182516440790582
#         ],
#         [
#           27.72840592909698,
#           -26.03484966112855
#         ],
#         [
#           27.482847725980587,
#           -25.9904458795519
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200126_082138_89_105d",
#   "properties": {
#     "acquired": "2020-01-26T08:21:38.895336Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 78,
#     "clear_percent": 54,
#     "cloud_cover": 0.24,
#     "cloud_percent": 15,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 9,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 21,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2023-08-11T19:37:45Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 280,
#     "satellite_id": "105d",
#     "shadow_percent": 1,
#     "snow_ice_percent": 0,
#     "strip_id": "3072924",
#     "sun_azimuth": 81.8,
#     "sun_elevation": 61,
#     "updated": "2023-08-11T19:37:45Z",
#     "view_angle": 4,
#     "visible_confidence_percent": 64,
#     "visible_percent": 76
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200126_082140_92_105d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200126_082140_92_105d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200126_082140_92_105d/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.453920486892738,
#           -26.119435047975067
#         ],
#         [
#           27.421038913557066,
#           -26.26646374259885
#         ],
#         [
#           27.666619822233802,
#           -26.311603686171292
#         ],
#         [
#           27.699531468497117,
#           -26.163899288103025
#         ],
#         [
#           27.453920486892738,
#           -26.119435047975067
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200126_082140_92_105d",
#   "properties": {
#     "acquired": "2020-01-26T08:21:40.928Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 71,
#     "clear_percent": 30,
#     "cloud_cover": 0.48,
#     "cloud_percent": 18,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 30,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 21,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2023-08-11T19:37:31Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 280.1,
#     "satellite_id": "105d",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3072924",
#     "sun_azimuth": 81.6,
#     "sun_elevation": 61,
#     "updated": "2023-08-11T19:37:31Z",
#     "view_angle": 4,
#     "visible_confidence_percent": 60,
#     "visible_percent": 52
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_075829_1014",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_075829_1014/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200123_075829_1014/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.339800410836794,
#           -26.199748430816257
#         ],
#         [
#           27.322539218246042,
#           -26.2739383645205
#         ],
#         [
#           27.577665890768706,
#           -26.321299172354397
#         ],
#         [
#           27.59426775347113,
#           -26.24705747241127
#         ],
#         [
#           27.339800410836794,
#           -26.199748430816257
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200123_075829_1014",
#   "properties": {
#     "acquired": "2020-01-23T07:58:29.804479Z",
#     "anomalous_pixels": 0.01,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-16T03:48:19Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 90.2,
#     "satellite_id": "1014",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3062336",
#     "sun_azimuth": 85.9,
#     "sun_elevation": 56.5,
#     "updated": "2021-03-16T03:48:19Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 99,
#     "visible_percent": 100
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_075828_1014",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_075828_1014/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200123_075828_1014/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.355128631120145,
#           -26.13476984507632
#         ],
#         [
#           27.337877796732958,
#           -26.20894241971228
#         ],
#         [
#           27.59286010921782,
#           -26.256273237416302
#         ],
#         [
#           27.60941981453503,
#           -26.18204411442655
#         ],
#         [
#           27.355128631120145,
#           -26.13476984507632
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200123_

#     "satellite_id": "1014",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3062336",
#     "sun_azimuth": 86.5,
#     "sun_elevation": 56.6,
#     "updated": "2021-03-16T03:48:00Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 100,
#     "visible_percent": 100
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_075818_1014",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_075818_1014/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200123_075818_1014/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.499850610074432,
#           -25.488926543804233
#         ],
#         [
#           27.48275502951364,
#           -25.5631204027796
#         ],
#         [
#           27.736505652163732,
#           -25.610306037686843
#         ],
#         [
#           27.752905054505938,
#           -25.536063523142438
#         ],
#         [
#           27.499850610074432,
#           -25.488926543804233
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200123_075818_1014",
#   "properties": {
#     "acquired": "2020-01-23T07:58:18.507646Z",
#     "anomalous_pixels": 0.01,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-16T03:48:00Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 89.1,
#     "satellite_id": "1014",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3062336",
#     "sun_azimuth": 87,
#     "sun_elevation": 56.6,
#     "updated": "2021-03-16T03:48:00Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 84,
#     "visible_percent": 100
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_075821_1014",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_075821_1014/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200123_075821_1014/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.456698185090463,
#           -25.681490069640535
#         ],
#         [
#           27.439640676089482,
#           -25.755721892604466
#         ],
#         [
#           27.69369617682246,
#           -25.80294588953196
#         ],
#         [
#           27.71019574848033,
#           -25.7286734926194
#         ],
#         [
#           27.456698185090463,
#           -25.681490069640535
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200123_075821_1014",
#   "properties": {
#     "acquired": "2020-01-23T07:58:21.588887Z",
#     "anomalous_pixels": 0.01,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-16T03:47:54Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 89.5,
#     "satellite_id": "1014",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3062336",
#     "sun_azimuth": 86.7,
#     "sun_elevation": 56.6,
#     "updated": "2021-03-16T03:47:54Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 99,
#     "visible_percent": 100
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_075819_1014",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_075819_1014/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200123_075819_1014/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.48526051172356,
#           -25.553129134869547
#         ],
#         [
#           27.46814932782648,
#           -25.627346749649867
#         ],
#         [
#           27.722011407671136,
#           -25.674560277549187
#         ],
#         [
#           27.738496737630644,
#           -25.600272830113465
#         ],
#         [
#           27.48526051172356,
#           -25.553129134869547
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200123_075819_1014",
#   "properties": {
#     "acquired": "2020-01-23T07:58:19.534726Z",
#     "anomalous_pixels": 0.01,
#     "clear_confidence_percent": 98,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-16T03:47:54Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 89.1,
#     "satellite_id": "1014",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3062336",
#     "sun_azimuth": 86.9,
#     "sun_elevation": 56.6,
#     "updated": "2021-03-16T03:47:54Z",
#     "view_angle": 1,
#     "visible_confidence_percent": 74,
#     "visible_percent": 100
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200103_075812_1014",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200103_075812_1014/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200103_075812_1014/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.865384684883367,
#           -25.823331568586436
#         ],
#         [
#           27.848628855621907,
#           -25.896672872081677
#         ],
#         [
#           28.101195976803123,
#           -25.942749514904065
#         ],
#         [
#           28.117486924132383,
#           -25.869007776842246
#         ],
#         [
#           27.865384684883367,
#           -25.823331568586436
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200103_075812_1014",
#   "properties": {
#     "acquired": "2020-01-03T07:58:12.346337Z",
#     "anomalous_pixels": 0.01,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-16T03:39:34Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 280.2,
#     "satellite_id": "1014",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "2995991",
#     "sun_azimuth": 91.8,
#     "sun_elevation": 59.1,
#     "updated": "2021-03-16T03:39:34Z",
#     "view_angle": 4.1,
#     "visible_confidence_percent": 100,
#     "visible_percent": 100
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200103_075815_1014",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200103_075815_1014/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200103_075815_1014/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.821900882194097,
#           -26.017754619220177
#         ],
#         [
#           27.80502650259183,
#           -26.091076684464245
#         ],
#         [
#           28.058090351248843,
#           -26.13716716362262
#         ],
#         [
#           28.074402315826923,
#           -26.063424455851862
#         ],
#         [
#           27.821900882194097,
#           -26.017754619220177
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200103_075815_1014",
#   "properties": {
#     "acquired": "2020-01-03T07:58:15.427578Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 100,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.9,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-16T03:39:28Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 279.8,
#     "satellite_id": "1014",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "2995991",
#     "sun_azimuth": 91.4,
#     "sun_elevation": 59.1,
#     "updated": "2021-03-16T03:39:28Z",
#     "view_angle": 4,
#     "visible_confidence_percent": 81,
#     "visible_percent": 100
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200103_075810_1014",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200103_075810_1014/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200103_075810_1014/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.893977736940016,
#           -25.69384711672842
#         ],
#         [
#           27.877358103478286,
#           -25.767222297537433
#         ],
#         [
#           28.129586083482746,
#           -25.81321555892601
#         ],
#         [
#           28.145816597755875,
#           -25.73947076926505
#         ],
#         [
# ...
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.893365518272144,
#           -29.072742397243058
#         ],
#         [
#           27.90835981861968,
#           -29.141440905512045
#         ],
#         [
#           28.15017540843782,
#           -29.09990979817371
#         ],
#         [
#           28.134703580884185,
#           -29.031349117102376
#         ],
#         [
#           27.893365518272144,
#           -29.072742397243058
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200123_073132_0f21",
#   "properties": {
#     "acquired": "2020-01-23T07:31:32.445708Z",
#     "anomalous_pixels": 0.01,
#     "clear_confidence_percent": 89,
#     "clear_percent": 90,
#     "cloud_cover": 0.07,
#     "cloud_percent": 6,
#     "ground_control": true,
#     "gsd": 3.6,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-12T21:28:50Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 1.2,
#     "satellite_id": "0f21",
#     "shadow_percent": 3,
#     "snow_ice_percent": 0,
#     "strip_id": "3061694",
#     "sun_azimuth": 85.6,
#     "sun_elevation": 50.8,
#     "updated": "2021-03-12T21:28:50Z",
#     "view_angle": 0.1,
#     "visible_confidence_percent": 61,
#     "visible_percent": 93
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200124_092851_55_106f",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200124_092851_55_106f/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200124_092851_55_106f/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.487560422049196,
#           -28.972023864638093
#         ],
#         [
#           27.52277627343854,
#           -29.12031512974963
#         ],
#         [
#           27.77789552757354,
#           -29.073755052201847
#         ],
#         [
#           27.741999077935148,
#           -28.924880627859714
#         ],
#         [
#           27.487560422049196,
#           -28.972023864638093
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200124_092851_55_106f",
#   "properties": {
#     "acquired": "2020-01-24T09:28:51.551327Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 92,
#     "clear_percent": 85,
#     "cloud_cover": 0.12,
#     "cloud_percent": 12,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-12T21:28:45Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 262.9,
#     "satellite_id": "106f",
#     "shadow_percent": 3,
#     "snow_ice_percent": 0,
#     "strip_id": "3065474",
#     "sun_azimuth": 54.8,
#     "sun_elevation": 74.3,
#     "updated": "2023-08-13T07:11:05Z",
#     "view_angle": 5.1,
#     "visible_confidence_percent": 79,
#     "visible_percent": 88
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_073136_0f21",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_073136_0f21/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200123_073136_0f21/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.83974991304776,
#           -28.835647797899323
#         ],
#         [
#           27.85461834588727,
#           -28.9043560946823
#         ],
#         [
#           28.095986643954163,
#           -28.8629362290876
#         ],
#         [
#           28.08052285135756,
#           -28.794366170598636
#         ],
#         [
#           27.83974991304776,
#           -28.835647797899323
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200123_073136_0f21",
#   "properties": {
#     "acquired": "2020-01-23T07:31:36.187027Z",
#     "anomalous_pixels": 0.01,
#     "clear_confidence_percent": 97,
#     "clear_percent": 96,
#     "cloud_cover": 0.03,
#     "cloud_percent": 3,
#     "ground_control": true,
#     "gsd": 3.6,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-12T21:28:45Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 1.6,
#     "satellite_id": "0f21",
#     "shadow_percent": 1,
#     "snow_ice_percent": 0,
#     "strip_id": "3061694",
#     "sun_azimuth": 85.9,
#     "sun_elevation": 50.8,
#     "updated": "2021-03-12T21:28:45Z",
#     "view_angle": 0.1,
#     "visible_confidence_percent": 76,
#     "visible_percent": 97
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200124_092857_71_106f",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200124_092857_71_106f/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200124_092857_71_106f/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.394822080610176,
#           -28.58345452029556
#         ],
#         [
#           27.429691419933484,
#           -28.731770750760955
#         ],
#         [
#           27.683670095051365,
#           -28.685364086281282
#         ],
#         [
#           27.64828359671368,
#           -28.536475111191834
#         ],
#         [
#           27.394822080610176,
#           -28.58345452029556
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200124_092857_71_106f",
#   "properties": {
#     "acquired": "2020-01-24T09:28:57.716954Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 80,
#     "clear_percent": 54,
#     "cloud_cover": 0.44,
#     "cloud_percent": 43,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 1,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-12T21:28:44Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 263.1,
#     "satellite_id": "106f",
#     "shadow_percent": 1,
#     "snow_ice_percent": 0,
#     "strip_id": "3065474",
#     "sun_azimuth": 56.1,
#     "sun_elevation": 74.4,
#     "updated": "2023-08-13T07:11:12Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 58,
#     "visible_percent": 56
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200124_092849_49_106f",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200124_092849_49_106f/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200124_092849_49_106f/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.51872660824485,
#           -29.10164096521582
#         ],
#         [
#           27.554094112029006,
#           -29.249940442879595
#         ],
#         [
#           27.809328681334307,
#           -29.2032308526252
#         ],
#         [
#           27.77345173893351,
#           -29.05437278831772
#         ],
#         [
#           27.51872660824485,
#           -29.10164096521582
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200124_092849_49_106f",
#   "properties": {
#     "acquired": "2020-01-24T09:28:49.496642Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 84,
#     "clear_percent": 64,
#     "cloud_cover": 0.33,
#     "cloud_percent": 33,
#     "ground_control": true,
#     "gsd": 3.8,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-12T21:28:44Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 262.7,
#     "satellite_id": "106f",
#     "shadow_percent": 3,
#     "snow_ice_percent": 0,
#     "strip_id": "3065474",
#     "sun_azimuth": 54.3,
#     "sun_elevation": 74.2,
#     "updated": "2023-08-13T07:09:50Z",
#     "view_angle": 5.1,
#     "visible_confidence_percent": 60,
#     "visible_percent": 67
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_073130_0f21",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_073130_0f21/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200123_073130_0f21/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.919765463823172,
#           -29.192296184226418
#         ],
#         [
#           27.934785670503732,
#           -29.26098436191539
#         ],
#         [
#           28.176782728860122,
#           -29.219480815581363
#         ],
#         [
#           28.16130017436709,
#           -29.150962217752895
#         ],
#         [
#           27.919765463823172,
#           -29.192296184226418
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200123_073130_0f21",
#   "properties": {
#     "acquired": "2020-01-23T07:31:30.575572Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 98,
#     "clear_percent": 99,
#     "cloud_cover": 0.01,
#     "cloud_percent": 1,
#     "ground_control": true,
#     "gsd": 3.6,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-12T21:28:44Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 6.6,
#     "satellite_id": "0f21",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3061694",
#     "sun_azimuth": 85.4,
#     "sun_elevation": 50.8,
#     "updated": "2021-03-12T21:28:44Z",
#     "view_angle": 0.1,
#     "visible_confidence_percent": 74,
#     "visible_percent": 99
#   },
#   "type": "Feature"
# }
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_073135_0f21",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20200123_073135_0f21/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20200123_073135_0f21/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_3b:download",
#     "assets.ortho_analytic_3b_xml:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_sr:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_udm2",
#     "ortho_analytic_3b",
#     "ortho_analytic_3b_xml",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_sr",
#     "ortho_analytic_4b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           27.85350223621685,
#           -28.894821138531018
#         ],
#         [
#           27.868434576256874,
#           -28.96351427102203
#         ],
#         [
#           28.109932300655732,
#           -28.92208641325813
#         ],
#         [
#           28.09439927392156,
#           -28.853533375998865
#         ],
#         [
#           27.85350223621685,
#           -28.894821138531018
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20200123_073135_0f21",
#   "properties": {
#     "acquired": "2020-01-23T07:31:35.251697Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 99,
#     "clear_percent": 100,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": true,
#     "gsd": 3.6,
#     "heavy_haze_percent": 0,
#     "instrument": "PS2",
#     "item_type": "PSScene",
#     "light_haze_percent": 0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2021-03-12T21:28:43Z",
#     "publishing_stage": "finalized",
#     "quality_category": "standard",
#     "satellite_azimuth": 1.6,
#     "satellite_id": "0f21",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "3061694",
#     "sun_azimuth": 85.8,
#     "sun_elevation": 50.8,
#     "updated": "2021-03-12T21:28:43Z",
#     "view_angle": 0.1,
#     "visible_confidence_percent": 71,
#     "visible_percent": 100
#   },
#   "type": "Feature"
# }

# %% [markdown]
# POST REQUEST THAT WILL LIST THE TOTAL NUMBER OF RESULTS ONLY.

# %%
# Function to send POST request and get total results count
def send_post_request(filters, item_type="PSScene"):
    search_request = {
        "item_types": [item_type],
        "filter": filters
    }
    
    search_result = requests.post(
        'https://api.planet.com/data/v1/quick-search',
        auth=HTTPBasicAuth(API_KEY, ''),
        json=search_request
    )
    
    geojson = search_result.json()
    
    if 'features' in geojson and geojson['features']:
        total_results = len(geojson['features'])
        print(f"Total number of results: {total_results}")
        return geojson['features']
    else:
        print("No results found.")
        return []

# Send POST requests and get total results count
print("Results for AOI1:")
features_AOI1 = send_post_request(filters_AOI1)

print("\nResults for AOI2:")
features_AOI2 = send_post_request(filters_AOI2)
# Out:
# Results for AOI1:
# Total number of results: 250
#
# Results for AOI2:
# Total number of results: 250

# %%
# Function to retrieve metadata for a single image ID
def get_image_metadata(image_id, item_type="PSScene"):
    id_url = f'https://api.planet.com/data/v1/item-types/{item_type}/items/{image_id}/assets'
    
    result = requests.get(
        id_url,
        auth=HTTPBasicAuth(API_KEY, '')
    )
    
    # List of asset types available for this particular satellite image
    print(f"Metadata for image ID {image_id}:")
    print(result.json().keys())

# %%
if features_AOI1:
    image_ids_AOI1 = [feature['id'] for feature in features_AOI1]
    print(f"Image IDs for AOI1: {image_ids_AOI1}")
    # Retrieve metadata for the first image ID
    if image_ids_AOI1:
        get_image_metadata(image_ids_AOI1[0]) #edit this to generate the correct image metadata for any of the 250 image ids. 

# Extract and print image IDs for AOI2
if features_AOI2:
    image_ids_AOI2 = [feature['id'] for feature in features_AOI2]
    print(f"Image IDs for AOI2: {image_ids_AOI2}")
    # Retrieve metadata for the first image ID
    if image_ids_AOI2:
        get_image_metadata(image_ids_AOI2[0]) #edit this
# Out:
# Image IDs for AOI1: ['20200105_092927_42_1069', '20200105_092925_39_1069', '20200126_082142_96_105d', '20200126_082138_89_105d', '20200126_082140_92_105d', '20200123_075829_1014', '20200123_075828_1014', '20200123_075826_1014', '20200123_075827_1014', '20200123_075824_1014', '20200123_075825_1014', '20200123_075822_1014', '20200123_075820_1014', '20200123_075823_1014', '20200123_075818_1014', '20200123_075821_1014', '20200123_075819_1014', '20200103_075812_1014', '20200103_075815_1014', '20200103_075810_1014', '20200103_075818_1014', '20200103_075816_1014', '20200103_075811_1014', '20200103_075813_1014', '20200103_075808_1014', '20200103_075807_1014', '20200103_075814_1014', '20200103_075817_1014', '20200103_075809_1014', '20200129_072925_0f46', '20200129_072928_0f46', '20200129_072924_0f46', '20200129_072920_0f46', '20200129_072919_0f46', '20200129_072926_0f46', '20200129_072929_0f46', '20200129_072923_0f46', '20200129_072920_1_0f46', '20200129_072922_0f46', '20200129_072921_0f46', '20200129_072927_0f46', '20200129_072918_0f46', '20200131_073102_0f3c', '20200131_073104_0f3c', '20200131_073059_0f3c', '20200131_073105_0f3c', '20200131_073100_0f3c', '20200131_073106_0f3c', '20200131_073103_0f3c', '20200131_073102_1_0f3c', '20200131_073101_0f3c', '20200130_072958_1052', '20200130_072959_1052', '20200130_072957_1052', '20200130_072955_1052', '20200130_072954_1052', '20200130_072
basic_analytic_4b', 'basic_analytic_4b_rpc', 'basic_analytic_4b_xml', 'basic_udm2', 'ortho_analytic_4b', 'ortho_analytic_4b_sr', 'ortho_analytic_4b_xml', 'ortho_udm2', 'ortho_visual'])

# %% [markdown]
# Asset Activation and Download Link generator

# %%
import requests
from requests.auth import HTTPBasicAuth
from tqdm import tqdm
import time

def activate_asset(item_id, asset_type='analytic'):
    item_type = 'PSScene'
    asset_url = f'https://api.planet.com/data/v1/item-types/{item_type}/items/{item_id}/assets/'
    
    # Request to get the asset details
    result = requests.get(asset_url, auth=HTTPBasicAuth(API_KEY, ''))
    asset_status = result.json()
    
    # Print the current status of the asset
    current_status = asset_status[asset_type]['status']
    print(f"Current status of asset {item_id}: {current_status}")
    
    if current_status != 'active':
        # Parse out useful links
        links = asset_status[asset_type]['_links']
        activation_link = links['activate']
        
        # Request activation of the asset
        print(f"Activating asset {item_id}...")
        activate_result = requests.get(activation_link, auth=HTTPBasicAuth(API_KEY, ''))
        
        if activate_result.status_code == 202:
            print(f"Activation request for asset {item_id} has been submitted successfully.")
        else:
            print(f"Failed to submit activation request for asset {item_id}. Status code: {activate_result.status_code}")
            return False

        # Check activation status with a progress bar
        with tqdm(total=100, desc="Activating", bar_format="{l_bar}{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}]") as pbar:
            while True:
                time.sleep(10)  # Wait for 10 seconds before checking the status again
                result = requests.get(asset_url, auth=HTTPBasicAuth(API_KEY, ''))
                asset_status = result.json()
                current_status = asset_status[asset_type]['status']
                
                if current_status == 'active':
                    print(f"Asset {item_id} is now active.")
                    break
                elif current_status == 'activating':
                    pbar.update(10)  # Update the progress bar
                else:
                    print(f"Asset {item_id} status: {current_status}")
                    break
    else:
        print(f"Asset {item_id} is already active.")

# %% [markdown]
# Usage

# %%
#USAGE
# item_id = '20200128_075448_1009'  # Replace with your selected image ID
# asset_type = 'basic_analytic_4b'  # You can change this to any other asset type if needed


# Example usage to activate an asset and get the download link
if image_ids_AOI1:
    selected_image_id = image_ids_AOI1[2]  # Replace with the desired image ID
    activate_asset(selected_image_id, asset_type='basic_analytic_4b')
# Out:
# Current status of asset 20200126_082142_96_105d: active
# Asset 20200126_082142_96_105d is already active.

# %% [markdown]
# LOG of assets already activated:
#
# 20200105_092927_42_1069
# 20200105_092925_39_1069
# 20200126_082142_96_105d

# %% [markdown]
# to solve the activation time, i will try to employ two solutions. (1) we can use multiprocessing to send multiple requests at the same time. (2) i will try to use batch request to send multiple image for activation in a single batch.
#
# an optimization that I think you can make on your part is use DUKE vpn given planet is based in the US.
#
# #an implementation that we would like to make as we refine this piece of code is to create a LOG of all the assets that are already activated.
# #another implementation is to use a for loop code to log send the activation request through the entire list.
# #another implementation is to create a log that will all activated assets. This should be in the helper code itself.
# #another implementation is to add other API keys and send requests simultanously

# %% [markdown]
# INFO about rate limiting:
#
# Rate Limiting
# To improve the experience for all of our users, Planet uses rate limiting to prevent overloading the system. If handled correctly, rate limiting errors can be a normal and useful part of working with the API.
#
# When a rate limit has been exceeded, the Planet API responds with an HTTP 429 response code. When this occurs, we recommend implementing retry with an exponential backoff. An exponential backoff means that you wait for exponentially longer intervals between each retry of a single failing request.
#
# The following rate limit is currently in place:
#
# Tasking endpoint: 10 requests per second, per API key.
# Maximum Payload Size¶
# When sending a POST request to the Planet API, the server will accept a maximum payload size of 1 megabyte.

# %%
import requests
from requests.auth import HTTPBasicAuth
from multiprocessing import Pool
import time

# Your Planet API key
API_KEY = 'PLAKe8a128a493104644888a58e5a0b4b780'

def activate_asset_optimized(item_id, asset_type='analytic'):
    item_type = 'PSScene'
    asset_url = f'https://api.planet.com/data/v1/item-types/{item_type}/items/{item_id}/assets/'
    
    # Request to get the asset details
    result = requests.get(asset_url, auth=HTTPBasicAuth(API_KEY, ''))
    asset_status = result.json()
    
    # Print the current status of the asset
    current_status = asset_status[asset_type]['status']
    print(f"Current status of asset {item_id}: {current_status}")
    
    if current_status != 'active':
        # Parse out useful links
        links = asset_status[asset_type]['_links']
        activation_link = links['activate']
        
        # Request activation of the asset
        print(f"Activating asset {item_id}...")
        activate_result = requests.get(activation_link, auth=HTTPBasicAuth(API_KEY, ''))
        
        if activate_result.status_code == 202:
            print(f"Activation request for asset {item_id} has been submitted successfully.")
        else:
            print(f"Failed to submit activation request for asset {item_id}. Status code: {activate_result.status_code}")
            return False

        # Check activation status
        while True:
            time.sleep(10)  # Wait for 10 seconds before checking the status again
            result = requests.get(asset_url, auth=HTTPBasicAuth(API_KEY, ''))
            asset_status = result.json()
            current_status = asset_status[asset_type]['status']
            
            if current_status == 'active':
                print(f"Asset {item_id} is now active.")
                return True
            elif current_status == 'activating':
                print(f"Asset {item_id} status: activating")
            else:
                print(f"Asset {item_id} status: {current_status}")
                return False
    else:
        print(f"Asset {item_id} is already active.")
        return True

def is_activated(image_id):
    # Check if image is already activated
    if image_id in activated_images:
        print(f"Image {image_id} is already activated.")
        return

    # Activate asset
    activate_asset_optimized(image_id, asset_type='basic_analytic_4b')

if __name__ == "__main__":
    # Load the list of already activated images from a log file or a list
    activated_images = [
        "20200105_092927_42_1069",
        "20200105_092925_39_1069",
        "20200126_082142_96_105d"
    ]

    # List of image IDs to activate
    # Assuming features_AOI1 is defined somewhere
    features_AOI1 = [{'id': '20200105_092927_42_1069'}, {'id': '20200105_092925_39_1069'}, {'id': '20200126_082142_96_105d'}]  # Add your actual features_AOI1 data here
    image_ids = [feature['id'] for feature in features_AOI1[:150]]  # Limit to 150 for this example

    # Use multiprocessing Pool to activate assets concurrently
    with Pool(10) as p:
        p.map(is_activated, image_ids)
# Out:
# Process SpawnPoolWorker-4:
# Process SpawnPoolWorker-6:
# Process SpawnPoolWorker-5:
# Process SpawnPoolWorker-3:
# Process SpawnPoolWorker-1:
# Process SpawnPoolWorker-2:
# Process SpawnPoolWorker-7:
# Process SpawnPoolWorker-8:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-9:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-10:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-11:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-12:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-13:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-14:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-15:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-17:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-16:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-18:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-19:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-20:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-21:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-22:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-23:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-24:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-25:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-26:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-27:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-28:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-29:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-30:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-31:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-32:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-33:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-34:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-35:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-36:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-37:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-38:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/ee/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'is_activated' on <module '__main__' (built-in)>
